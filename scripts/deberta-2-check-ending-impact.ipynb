# %%
import json
import pandas as  pd

# %% [markdown]
# # Loading Data

# %%
TRAIN_JSON_FILE = "../data/train.json"
DEV_JSON_FILE = "../data/dev.json"

def load_data(file_path):
    """
    Loads the json containing the dataset and return a pandas dataframe.
    """
    with open(file_path, 'r') as f:
        data = json.load(f)
    # Transpose because the json is {id: {features...}, ...}
    df = pd.DataFrame(data).T
    # Ensure 'average' is float
    df['average'] = df['average'].astype(float)
    # Ensure 'choices' is list (for scoring later)
    return df

df_train = load_data(TRAIN_JSON_FILE)
df_dev = load_data(DEV_JSON_FILE)

# %%
df_dev.reset_index()
# Out:
#     index  homonym                                     judged_meaning  \
# 0       0    track  a pair of parallel rails providing a runway fo...
# 1       1    track           evidence pointing to a possible solution
# 2       2    track  a pair of parallel rails providing a runway fo...
# 3       3    track           evidence pointing to a possible solution
# 4       4    track  a pair of parallel rails providing a runway fo...
# ..    ...      ...                                                ...
# 583   583  trailer  a wheeled vehicle that can be pulled by a car ...
# 584   584  trailer  an advertisement consisting of short scenes fr...
# 585   585  trailer  a wheeled vehicle that can be pulled by a car ...
# 586   586  trailer  an advertisement consisting of short scenes fr...
# 587   587  trailer  a wheeled vehicle that can be pulled by a car ...
#
#                                             precontext  \
# 0    The detectives arrived at the abandoned train ...
# 1    The detectives arrived at the abandoned train ...
# 2    The detectives arrived at the abandoned train ...
# 3    The detectives arrived at the abandoned train ...
# 4    The detectives arrived at the abandoned train ...
# ..                                                 ...
# 583  Emma glanced at her phone, checking the time. ...
# 584  Emma glanced at her phone, checking the time. ...
# 585  Emma glanced at her phone, checking the time. ...
# 586  Emma glanced at her phone, checking the time. ...
# 587  Emma glanced at her phone, checking the time. ...
#
#                                               sentence  \
# 0                             They followed the track.
# 1                             They followed the track.
# 2                             They followed the track.
# 3                             They followed the track.
# 4                             They followed the track.
# ..                                                 ...
# 583  She really didn't want to go to the trailer to...
# 584  She really didn't want to go to the trailer to...
# 585  She really didn't want to go to the trailer to...
# 586  She really didn't want to go to the trailer to...
# 587  She really didn't want to go to the trailer to...
#
#                                                 ending          choices  \
# 0    They began to run along the abandoned railway ...  [4, 5, 3, 1, 5]
# 1    They began to run along the abandoned railway ...  [3, 3, 4, 4, 4]
# 2    They found interesting clues that helped them ...  [5, 5, 2, 3, 4]
# 3    They found interesting clues that helped them ...  [4, 5, 4, 3, 5]
# 4                                                       [1, 5, 4, 4, 1]
# ..                                                 ...              ...
# 583        She had no interest in going to the movies.  [1, 1, 3, 1, 1]
# 584  She still has nightmares from the last time sh...  [2, 5, 1, 1, 1]
# 585  She still has nightmares from the last time sh...  [4, 5, 5, 5, 4]
# 586                                                     [3, 2, 1, 3, 2]
# 587                                                     [2, 3, 3, 3, 1]
#
#      average     stdev                          nonsensical sample_id  \
# 0        3.6   1.67332  [False, False, False, False, False]      2371
# 1        3.6  0.547723  [False, False, False, False, False]      2372
# 2        3.8   1.30384  [False, False, False, False, False]      2373
# 3        4.2   0.83666  [False, False, False, False, False]      2374
# 4        3.0  1.870829  [False, False, False, False, False]      2375
# ..       ...       ...                                  ...       ...
# 583      1.4  0.894427   [False, True, False, False, False]      3434
# 584      2.0  1.732051  [False, False, False, False, False]      3435
# 585      4.6  0.547723  [False, False, False, False, False]      3436
# 586      2.2   0.83666  [False, False, False, False, False]      3437
# 587      2.4  0.894427  [False, False, False, False, False]      3438
#
#                                   example_sentence
# 0       The train glided smoothly along the track.
# 1             The detective found a crucial track.
# 2       The train glided smoothly along the track.
# 3             The detective found a crucial track.
# 4       The train glided smoothly along the track.
# ..                                             ...
# 583  They traveled cross-country in their trailer.
# 584        I watched the new movie trailer online.
# 585  They traveled cross-country in their trailer.
# 586        I watched the new movie trailer online.
# 587  They traveled cross-country in their trailer.
#
# [588 rows x 12 columns]

# %%
# define a function to check that the story has no ending
def check_ending(x):
    if x=="":
        return True
    else:
        return False

# %%
df_dev['has_no_ending'] = df_dev['ending'].apply(check_ending)

# %%
no_endings_dict = df_dev['has_no_ending'].to_dict()

# %% [markdown]
# # Splitting Predictions Part

# %%
from pathlib import Path
# helper to read jsonl
def read_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        return [json.loads(line) for line in f if line.strip()]

# load data
predictions = read_jsonl("../deberta-finetune-2/predictions.jsonl")
references  = read_jsonl("../deberta-finetune-2/ref.jsonl")

# your dictionary: id → True/False
# no_endings_dict = {...}

# output folders
Path("../deberta-finetune-2-no_ending").mkdir(exist_ok=True)
Path("../deberta-finetune-2-with_ending").mkdir(exist_ok=True)

# containers
preds_no = []
refs_no = []

preds_yes = []
refs_yes = []

# simple loop
for pred, ref in zip(predictions, references):
    pid = pred["id"]
    has_no_ending = no_endings_dict[pid]

    if has_no_ending:
        preds_no.append(pred)
        refs_no.append(ref)
    else:
        preds_yes.append(pred)
        refs_yes.append(ref)

# write helper
def write_jsonl(path, items):
    with open(path, "w", encoding="utf-8") as f:
        for x in items:
            f.write(json.dumps(x) + "\n")



def renumber(records):
    for i, rec in enumerate(records, start=0):
        rec["id"] = str(i)      # IMPORTANT: store as "1", "2", "3"...
    return records

# Renumber for each bucket
preds_no  = renumber(preds_no)
refs_no   = renumber(refs_no)
preds_yes = renumber(preds_yes)
refs_yes  = renumber(refs_yes)

# save
write_jsonl("../deberta-finetune-2-no_ending/predictions.jsonl", preds_no)
write_jsonl("../deberta-finetune-2-no_ending/ref.jsonl", refs_no)

write_jsonl("../deberta-finetune-2-with_ending/predictions.jsonl", preds_yes)
write_jsonl("../deberta-finetune-2-with_ending/ref.jsonl", refs_yes)

print("Done!")
# Out:
# Done!

# %%
len(preds_yes), len(refs_yes)
# Out:
# (392, 392)

# %%
import subprocess
import os
import sys

OUT_DIR_ENDING = "../deberta-finetune-2-with_ending"
ref_file = os.path.join(OUT_DIR_ENDING,"ref.jsonl")
pred_file = os.path.join(OUT_DIR_ENDING,"predictions.jsonl")
res = subprocess.run([sys.executable, "../score/scoring.py", ref_file, pred_file, os.path.join(OUT_DIR_ENDING, "score.json")], capture_output=True, text=True)
# Out:
# CompletedProcess(args=['python', '../score/scoring.py', '../deberta-finetune-2-with_ending\\ref.jsonl', '../deberta-finetune-2-with_ending\\predictions.jsonl', '../deberta-finetune-2-with_ending\\score.json'], returncode=1, stdout='Importing...\n', stderr='Traceback (most recent call last):\n  File "D:\\Polito\\First Year\\LLM4SE\\WSD_Project\\LLM-SemEval-T5\\score\\scoring.py", line 8, in <module>\n    from scipy.stats import spearmanr\nModuleNotFoundError: No module named \'scipy\'\n')

# %%
OUT_DIR_NO_ENDING = "../deberta-finetune-2-no_ending"
ref_file_no_end = os.path.join(OUT_DIR_NO_ENDING,"ref.jsonl")
pred_file_no_end = os.path.join(OUT_DIR_NO_ENDING,"predictions.jsonl")
res = subprocess.run([sys.executable, "../score/scoring.py", ref_file_no_end, pred_file_no_end, os.path.join(OUT_DIR_NO_ENDING, "score.json")], capture_output=True, text=True)

# %%
# %%sql
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 raise Exception(__import__('base64').b64decode('VmFyaWFibGUgTmFtZSBpcyBub3QgY2hvc2Vu').decode('utf-8'))
#
# Exception: Variable Name is not chosen

# %%
res
# Out:
# CompletedProcess(args=['D:\\Polito\\First Year\\LLM4SE\\WSD_Project\\LLM-SemEval-T5\\.venv\\Scripts\\python.exe', '../score/scoring.py', '../deberta-finetune-2-with_ending\\ref.jsonl', '../deberta-finetune-2-with_ending\\predictions.jsonl', '../deberta-finetune-2-with_ending\\score.json'], returncode=0, stdout='Importing...\nStarting Scoring script...\nWarning: The following lines do not have expected values (1-5). Evaluation can still take place but please check your data.\n[\'{"id": "334", "prediction": 0.93243408203125}\\n\', \'{"id": "361", "prediction": 0.98797607421875}\\n\']\nEverything looks OK. Evaluating file ../deberta-finetune-2-with_ending\\predictions.jsonl on ../deberta-finetune-2-with_ending\\ref.jsonl\n----------\nSpearman Correlation: 0.7071328367889339\nSpearman p-Value: 1.1179873976431216e-60\n----------\nAccuracy: 0.8214285714285714 (322/392)\nResults dumped into scores.json successfully.\n', stderr='')
